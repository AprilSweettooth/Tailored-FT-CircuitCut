# %%
from benchmark_2D_Ising import *

# %%
# wire_cut_only_data = run(ratio_list=[0.5], lattice_size=range(4,5), only_wire=True, record=False)

# %%
data = run(ratio_list=[0.5, 0.7, 0.9], lattice_size=range(3,7))
# Out:
# number of time steps:  4
# max no. of qubit per subcircuit:  4
# Found 3x3 Ising model solution using 720 cuts (720 gate 0 wire cuts)
# ....
#  total physical qubits required:  22280
#  total runtime 0.7112820000000001
#
#  logical depth 118547 algo depth 6844 physical qubits 450
# ....
#  subcircuit- 1 : physical qubits-- 11708 runtime (in microsec)-- 16816.8
#
#  logical depth 3234 algo depth 315 physical qubits 338
# ......
#  subcircuit- 2 : physical qubits-- 20270 runtime (in microsec)-- 350442.0
#
#  logical depth 58407 algo depth 2580 physical qubits 450
# ....
#  subcircuit- 3 : physical qubits-- 26670 runtime (in microsec)-- 641784.0
#
#  logical depth 94380 algo depth 3901 physical qubits 578
#
#  quantum runtime total:  1.0090428 number of physical qubits:  26670
# number of time steps:  9
# max no. of qubit per subcircuit:  8
# Found 4x4 Ising model solution using 1620 cuts (1620 gate 0 wire cuts)
# ....
#  total physical qubits required:  39530
#  total runtime 3.6190348
#
#  logical depth 532211 algo depth 23522 physical qubits 578
# ....
#  subcircuit- 1 : physical qubits-- 32450 runtime (in microsec)-- 1983152.0
#
#  logical depth 291640 algo depth 12760 physical qubits 578
# ....
#  subcircuit- 2 : physical qubits-- 45950 runtime (in microsec)-- 3377782.0
#
#  logical depth 444445 algo depth 15866 physical qubits 722
#
#  quantum runtime total:  5.360934 number of physical qubits:  45950
# number of time steps:  15
# max no. of qubit per subcircuit:  12
# Found 5x5 Ising model solution using 4350 cuts (4350 gate 0 wire cuts)
# ......
#  total physical qubits required:  65652
#  total runtime 12.7946152
#
#  logical depth 1683502 algo depth 54717 physical qubits 722
# ....
#  subcircuit- 1 : physical qubits-- 11708 runtime (in microsec)-- 65208.0
#
#  logical depth 12540 algo depth 1216 physical qubits 338
# ....
#  subcircuit- 2 : physical qubits-- 43270 runtime (in microsec)-- 5981473.600000001
#
#  logical depth 787036 algo depth 29280 physical qubits 722
# ....
#  subcircuit- 3 : physical qubits-- 43270 runtime (in microsec)-- 8465472.8
#
#  logical depth 1113878 algo depth 34830 physical qubits 722
#
#  quantum runtime total:  14.512154400000002 number of physical qubits:  43270
# number of time steps:  23
# max no. of qubit per subcircuit:  18
# Found 6x6 Ising model solution using 6440 cuts (6440 gate 0 wire cuts)
# ........
#  total physical qubits required:  82980
#  total runtime 32.4344212
#
#  logical depth 4267687 algo depth 110684 physical qubits 722
# .......
#  subcircuit- 1 : physical qubits-- 53378 runtime (in microsec)-- 15892329.6
#
#  logical depth 2091096 algo depth 62942 physical qubits 722
# .....
#  subcircuit- 2 : physical qubits-- 61218 runtime (in microsec)-- 21618777.6
#
#  logical depth 2573664 algo depth 72487 physical qubits 882
#
#  quantum runtime total:  37.511107200000005 number of physical qubits:  61218
# number of time steps:  4
# max no. of qubit per subcircuit:  6
# Found 3x3 Ising model solution using 520 cuts (520 gate 0 wire cuts)
# ....
#  total physical qubits required:  22280
#  total runtime 0.7112820000000001
#
#  logical depth 118547 algo depth 6844 physical qubits 450
# ....
#  subcircuit- 1 : physical qubits-- 18920 runtime (in microsec)-- 154674.0
#
#  logical depth 25779 algo depth 1759 physical qubits 450
# ....
#  subcircuit- 2 : physical qubits-- 29560 runtime (in microsec)-- 970278.4
#
#  logical depth 142688 algo depth 5463 physical qubits 578
#
#  quantum runtime total:  1.1249524 number of physical qubits:  29560
# number of time steps:  9
# max no. of qubit per subcircuit:  11
# Found 4x4 Ising model solution using 1440 cuts (1440 gate 0 wire cuts)
# ......
#  total physical qubits required:  39530
#  total runtime 3.6190348
#
#  logical depth 532211 algo depth 23522 physical qubits 578
# ....
#  subcircuit- 1 : physical qubits-- 28404 runtime (in microsec)-- 961792.0
#
#  logical depth 141440 algo depth 7582 physical qubits 578
# ....
#  subcircuit- 2 : physical qubits-- 41826 runtime (in microsec)-- 4414900.8
#
#  logical depth 580908 algo depth 18884 physical qubits 722
#
#  quantum runtime total:  5.376692800000001 number of physical qubits:  41826
# number of time steps:  15
# max no. of qubit per subcircuit:  17
# Found 5x5 Ising model solution using 2850 cuts (2850 gate 0 wire cuts)
# .....
#  total physical qubits required:  65652
#  total runtime 12.7946152
#
#  logical depth 1683502 algo depth 54717 physical qubits 722
# ....
#  subcircuit- 1 : physical qubits-- 45950 runtime (in microsec)-- 3377782.0
#
#  logical depth 444445 algo depth 25076 physical qubits 722
# ....
#  subcircuit- 2 : physical qubits-- 51934 runtime (in microsec)-- 11697616.0
#
#  logical depth 1539160 algo depth 46611 physical qubits 722
#
#  quantum runtime total:  15.075398000000002 number of physical qubits:  51934
# number of time steps:  23
# max no. of qubit per subcircuit:  25
# Found 6x6 Ising model solution using 5750 cuts (5750 gate 0 wire cuts)
# ........
#  total physical qubits required:  82980
#  total runtime 32.4344212
#
#  logical depth 4267687 algo depth 110684 physical qubits 722
# ....
#  subcircuit- 1 : physical qubits-- 41826 runtime (in microsec)-- 7445378.0
#
#  logical depth 979655 algo depth 47984 physical qubits 722
# ........
#  subcircuit- 2 : physical qubits-- 76212 runtime (in microsec)-- 28900368.0
#
#  logical depth 3440520 algo depth 87214 physical qubits 882
#
#  quantum runtime total:  36.345746000000005 number of physical qubits:  76212
# number of time steps:  4
# max no. of qubit per subcircuit:  8
# Found 3x3 Ising model solution using 280 cuts (280 gate 0 wire cuts)
# ....
#  total physical qubits required:  22280
#  total runtime 0.7112820000000001
#
#  logical depth 118547 algo depth 6844 physical qubits 450
# ....
#  subcircuit- 1 : physical qubits-- 11708 runtime (in microsec)-- 16816.8
#
#  logical depth 3234 algo depth 315 physical qubits 338
# ....
#  subcircuit- 2 : physical qubits-- 32450 runtime (in microsec)-- 1142835.2
#
#  logical depth 168064 algo depth 6265 physical qubits 578
#
#  quantum runtime total:  1.1596520000000001 number of physical qubits:  32450
# number of time steps:  9
# max no. of qubit per subcircuit:  14
# Found 4x4 Ising model solution using 900 cuts (900 gate 0 wire cuts)
# ....
#  total physical qubits required:  39530
#  total runtime 3.6190348
#
#  logical depth 532211 algo depth 23522 physical qubits 578
# ....
#  subcircuit- 1 : physical qubits-- 17570 runtime (in microsec)-- 196854.0
#
#  logical depth 32809 algo depth 2358 physical qubits 450
# ....
#  subcircuit- 2 : physical qubits-- 46880 runtime (in microsec)-- 5239584.4
#
#  logical depth 689419 algo depth 22622 physical qubits 722
#
#  quantum runtime total:  5.4364384 number of physical qubits:  46880
# number of time steps:  15
# max no. of qubit per subcircuit:  22
# Found 5x5 Ising model solution using 1950 cuts (1950 gate 0 wire cuts)
# .....
#  total physical qubits required:  65652
#  total runtime 12.7946152
#
#  logical depth 1683502 algo depth 54717 physical qubits 722
# ......
#  subcircuit- 1 : physical qubits-- 34836 runtime (in microsec)-- 629632.4
#
#  logical depth 92593 algo depth 6920 physical qubits 578
# .....
#  subcircuit- 2 : physical qubits-- 79938 runtime (in microsec)-- 15819216.0
#
#  logical depth 1883240 algo depth 53891 physical qubits 882
#
#  quantum runtime total:  16.4488484 number of physical qubits:  79938
# number of time steps:  23
# max no. of qubit per subcircuit:  32
# Found 6x6 Ising model solution using 3680 cuts (3680 gate 0 wire cuts)
# ........
#  total physical qubits required:  82980
#  total runtime 32.4344212
#
#  logical depth 4267687 algo depth 110684 physical qubits 722
# ....
#  subcircuit- 1 : physical qubits-- 26670 runtime (in microsec)-- 1804856.0
#
#  logical depth 265420 algo depth 14856 physical qubits 578
# .......
#  subcircuit- 2 : physical qubits-- 89442 runtime (in microsec)-- 35300966.4
#
#  logical depth 4202496 algo depth 105851 physical qubits 882
#
#  quantum runtime total:  37.1058224 number of physical qubits:  89442

# %%
# import json

# with open('2D_Ising_data.json', 'w') as fp:
#     json.dump(data, fp)

# with open('data.json', 'r') as fp:
#     data = json.load(fp)
